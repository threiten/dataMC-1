# %%
from quantileRegression import quantileRegression
import numpy as np
import runNumbers as rn
import Plotting as plot
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
from pandas import Series, DataFrame
plt.style.use('ggplot')
import pandas as  pd
# Out:
# Welcome to ROOTaaS 6.06/08

# %%
#---------------------------------------------------------------------
#TEST USING QUANTILE REGRESSION ON EB/EE DATA SEPARATELY AND UNIFIED AFTERWARDS, WITH AND WITHOUT WEIGHTS
#---------------------------------------------------------------------

# %%
#Load different DF:
#10: step+weightedPU
#13: runperiod+weighted PU
#19: runnumber-no PU (aggiunto dopo)
dfmc10=pd.read_hdf("df_mc_10.h5", 'df')
dfmc13=pd.read_hdf("df_mc_13.h5", 'df')
dfmc19=pd.read_hdf("df_mc_19.h5", 'df')
dfdata10=pd.read_hdf("df_data_10.h5", 'df')
dfdata13=pd.read_hdf("df_data_13.h5", 'df')
dfdata19=pd.read_hdf("df_data_19.h5", 'df')

# %%
rv = np.arange(0.0,1.1,0.01)
rv2 = np.arange(0.9,1.1,0.001)

fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel("R9")
  
plot.plotHistRatio(dfdata10["R9"],dfmc10["R9_corr"], rv,Weight1=dfdata10["weight"],Weight2=dfmc10["weight"], Color="b")
plot.plotHistRatio(dfdata13["R9"],dfmc13["R9_corr"], rv,Weight1=dfdata19["weight"],Weight2=dfmc13["weight"], Color="g")
plot.plotHistRatio(dfdata19["R9"],dfmc19["R9_corr"], rv,Weight1=dfdata13["weight"],Weight2=dfmc19["weight"], Color="r")

ax.set_title('Ratio')
ax.set_ylim(-5,5)

fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel("Ratio")
    
plot.plotHistRatio(dfdata10["R9"],dfmc10["R9_corr"], rv2,Weight1=dfdata10["weight"],Weight2=dfmc10["weight"], Color="b")
plot.plotHistRatio(dfdata13["R9"],dfmc13["R9_corr"], rv2,Weight1=dfdata13["weight"],Weight2=dfmc13["weight"], Color="g")
plot.plotHistRatio(dfdata19["R9"],dfmc19["R9_corr"], rv2,Weight1=dfdata19["weight"],Weight2=dfmc19["weight"], Color="r")
ax.set_ylim(0,6)
ax.set_xlim(0.9,1.1)
ax.set_title('ratio')

# %%
rv = np.arange(0.3,1.0,0.02)
rv2 = np.arange(0.9,1.0,0.0025)

partialdata10=dfdata10.query("runperiod==1")
partialdata13=dfdata13.query("runperiod==1")
partialdata19=dfdata19.query("runperiod==1")

partialmc10=dfmc10.query("runperiod==1")
partialmc13=dfmc13.query("runperiod==1")
partialmc19=dfmc19.query("runperiod==1")

#BD
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel("R9")



plot.plotHistRatio(partialdata10["R9"],partialmc10["R9_corr"], rv,Weight1=partialdata10["weight"],Weight2=partialmc10["weight"], Color="b")
plot.plotHistRatio(partialdata13["R9"],partialmc13["R9_corr"], rv,Weight1=partialdata13["weight"],Weight2=partialmc13["weight"], Color="g")
plot.plotHistRatio(partialdata19["R9"],partialmc19["R9_corr"], rv,Weight1=partialdata19["weight"],Weight2=partialmc19["weight"], Color="r")

ax.set_title('BD')
#ax.set_ylim(-5,5)

fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel("Ratio")
    
plot.plotHistRatio(partialdata10["R9"],partialmc10["R9_corr"], rv2,Weight1=partialdata10["weight"],Weight2=partialmc10["weight"], Color="b")
plot.plotHistRatio(partialdata13["R9"],partialmc13["R9_corr"], rv2,Weight1=partialdata13["weight"],Weight2=partialmc13["weight"], Color="g")
plot.plotHistRatio(partialdata19["R9"],partialmc19["R9_corr"], rv2,Weight1=partialdata19["weight"],Weight2=partialmc19["weight"], Color="r")
ax.set_ylim(0,2)
#ax.set_xlim(0.9,1.1)
ax.set_title('BD')
partialdata10=dfdata10.query("runperiod==2")
partialdata13=dfdata13.query("runperiod==2")
partialdata19=dfdata19.query("runperiod==2")

partialmc10=dfmc10.query("runperiod==2")
partialmc13=dfmc13.query("runperiod==2")
partialmc19=dfmc19.query("runperiod==2")

#E
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel("R9")



plot.plotHistRatio(partialdata10["R9"],partialmc10["R9_corr"], rv,Weight1=partialdata10["weight"],Weight2=partialmc10["weight"], Color="b")
plot.plotHistRatio(partialdata13["R9"],partialmc13["R9_corr"], rv,Weight1=partialdata13["weight"],Weight2=partialmc13["weight"], Color="g")
plot.plotHistRatio(partialdata19["R9"],partialmc19["R9_corr"], rv,Weight1=partialdata19["weight"],Weight2=partialmc19["weight"], Color="r")

ax.set_title('E')
#ax.set_ylim(-5,5)

fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel("Ratio")
    
plot.plotHistRatio(partialdata10["R9"],partialmc10["R9_corr"], rv2,Weight1=partialdata10["weight"],Weight2=partialmc10["weight"], Color="b")
plot.plotHistRatio(partialdata13["R9"],partialmc13["R9_corr"], rv2,Weight1=partialdata13["weight"],Weight2=partialmc13["weight"], Color="g")
plot.plotHistRatio(partialdata19["R9"],partialmc19["R9_corr"], rv2,Weight1=partialdata19["weight"],Weight2=partialmc19["weight"], Color="r")
ax.set_ylim(0,2)
#ax.set_xlim(0.9,1.1)
ax.set_title('E')
partialdata10=dfdata10.query("runperiod==3")
partialdata13=dfdata13.query("runperiod==3")
partialdata19=dfdata19.query("runperiod==3")

partialmc10=dfmc10.query("runperiod==3")
partialmc13=dfmc13.query("runperiod==3")
partialmc19=dfmc19.query("runperiod==3")

#BD
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel("R9")



plot.plotHistRatio(partialdata10["R9"],partialmc10["R9_corr"], rv,Weight1=partialdata10["weight"],Weight2=partialmc10["weight"], Color="b")
plot.plotHistRatio(partialdata13["R9"],partialmc13["R9_corr"], rv,Weight1=partialdata13["weight"],Weight2=partialmc13["weight"], Color="g")
plot.plotHistRatio(partialdata19["R9"],partialmc19["R9_corr"], rv,Weight1=partialdata19["weight"],Weight2=partialmc19["weight"], Color="r")

ax.set_title('F')
#ax.set_ylim(-5,5)

fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel("Ratio")
    
plot.plotHistRatio(partialdata10["R9"],partialmc10["R9_corr"], rv2,Weight1=partialdata10["weight"],Weight2=partialmc10["weight"], Color="b")
plot.plotHistRatio(partialdata13["R9"],partialmc13["R9_corr"], rv2,Weight1=partialdata13["weight"],Weight2=partialmc13["weight"], Color="g")
plot.plotHistRatio(partialdata19["R9"],partialmc19["R9_corr"], rv2,Weight1=partialdata19["weight"],Weight2=partialmc19["weight"], Color="r")
ax.set_ylim(0,2)
#ax.set_xlim(0.9,1.1)
ax.set_title('F')
partialdata10=dfdata10.query("runperiod==4")
partialdata13=dfdata13.query("runperiod==4")
partialdata19=dfdata19.query("runperiod==4")

partialmc10=dfmc10.query("runperiod==4")
partialmc13=dfmc13.query("runperiod==4")
partialmc19=dfmc19.query("runperiod==4")

#BD
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel("R9")



plot.plotHistRatio(partialdata10["R9"],partialmc10["R9_corr"], rv,Weight1=partialdata10["weight"],Weight2=partialmc10["weight"], Color="b")
plot.plotHistRatio(partialdata13["R9"],partialmc13["R9_corr"], rv,Weight1=partialdata13["weight"],Weight2=partialmc13["weight"], Color="g")
plot.plotHistRatio(partialdata19["R9"],partialmc19["R9_corr"], rv,Weight1=partialdata19["weight"],Weight2=partialmc19["weight"], Color="r")

ax.set_title('G')
#ax.set_ylim(-5,5)

fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel("Ratio")
    
plot.plotHistRatio(partialdata10["R9"],partialmc10["R9_corr"], rv2,Weight1=partialdata10["weight"],Weight2=partialmc10["weight"], Color="b")
plot.plotHistRatio(partialdata13["R9"],partialmc13["R9_corr"], rv2,Weight1=partialdata13["weight"],Weight2=partialmc13["weight"], Color="g")
plot.plotHistRatio(partialdata19["R9"],partialmc19["R9_corr"], rv2,Weight1=partialdata19["weight"],Weight2=partialmc19["weight"], Color="r")
ax.set_ylim(0,2)
#ax.set_xlim(0.9,1.1)
ax.set_title('G')
partialdata10=dfdata10.query("runperiod==5")
partialdata13=dfdata13.query("runperiod==5")
partialdata19=dfdata19.query("runperiod==5")

partialmc10=dfmc10.query("runperiod==5")
partialmc13=dfmc13.query("runperiod==5")
partialmc19=dfmc19.query("runperiod==5")

#BD
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel("R9")



plot.plotHistRatio(partialdata10["R9"],partialmc10["R9_corr"], rv,Weight1=partialdata10["weight"],Weight2=partialmc10["weight"], Color="b")
plot.plotHistRatio(partialdata13["R9"],partialmc13["R9_corr"], rv,Weight1=partialdata13["weight"],Weight2=partialmc13["weight"], Color="g")
plot.plotHistRatio(partialdata19["R9"],partialmc19["R9_corr"], rv,Weight1=partialdata19["weight"],Weight2=partialmc19["weight"], Color="r")

ax.set_title('H')
#ax.set_ylim(-5,5)

fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel("Ratio")
    
plot.plotHistRatio(partialdata10["R9"],partialmc10["R9_corr"], rv2,Weight1=partialdata10["weight"],Weight2=partialmc10["weight"], Color="b")
plot.plotHistRatio(partialdata13["R9"],partialmc13["R9_corr"], rv2,Weight1=partialdata13["weight"],Weight2=partialmc13["weight"], Color="g")
plot.plotHistRatio(partialdata19["R9"],partialmc19["R9_corr"], rv2,Weight1=partialdata19["weight"],Weight2=partialmc19["weight"], Color="r")
ax.set_ylim(0,2)
#ax.set_xlim(0.9,1.1)
ax.set_title('H')

# %%
rv = np.arange(0.3,1.0,0.02)
rv2 = np.arange(0.9,1.0,0.0025)

partialdata10=dfdata10.query("runperiod==1")
partialdata13=dfdata10.query("runperiod==1")
partialdata19=dfdata10.query("runperiod==1")

partialmc10=dfmc10.query("runperiod==1")
partialmc13=dfmc13.query("runperiod==1")
partialmc19=dfmc19.query("runperiod==1")

#BD
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel("R9")



plot.plotHistRatio(partialdata10["R9"],partialmc10["R9_corr"], rv,Weight1=partialdata10["weight"],Weight2=partialmc10["weight"], Color="b")
plot.plotHistRatio(partialdata13["R9"],partialmc13["R9_corr"], rv,Weight1=partialdata13["weight"],Weight2=partialmc13["weight"], Color="g")
plot.plotHistRatio(partialdata19["R9"],partialmc19["R9_corr"], rv,Weight1=partialdata19["weight"],Weight2=partialmc19["weight"], Color="r")

ax.set_title('BD')
#ax.set_ylim(-5,5)

fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel("Ratio")
    
plot.plotHistRatio(partialdata10["R9"],partialmc10["R9_corr"], rv2,Weight1=partialdata10["weight"],Weight2=partialmc10["weight"], Color="b")
plot.plotHistRatio(partialdata13["R9"],partialmc13["R9_corr"], rv2,Weight1=partialdata13["weight"],Weight2=partialmc13["weight"], Color="g")
plot.plotHistRatio(partialdata19["R9"],partialmc19["R9_corr"], rv2,Weight1=partialdata19["weight"],Weight2=partialmc19["weight"], Color="r")
ax.set_ylim(0,2)
#ax.set_xlim(0.9,1.1)
ax.set_title('BD')
partialdata10=dfdata10.query("runperiod==2")
partialdata13=dfdata10.query("runperiod==2")
partialdata19=dfdata10.query("runperiod==2")

partialmc10=dfmc10.query("runperiod==2")
partialmc13=dfmc13.query("runperiod==2")
partialmc19=dfmc19.query("runperiod==2")

#E
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel("R9")



plot.plotHistRatio(partialdata10["R9"],partialmc10["R9_corr"], rv,Weight1=partialdata10["weight"],Weight2=partialmc10["weight"], Color="b")
plot.plotHistRatio(partialdata13["R9"],partialmc13["R9_corr"], rv,Weight1=partialdata13["weight"],Weight2=partialmc13["weight"], Color="g")
plot.plotHistRatio(partialdata19["R9"],partialmc19["R9_corr"], rv,Weight1=partialdata19["weight"],Weight2=partialmc19["weight"], Color="r")

ax.set_title('E')
#ax.set_ylim(-5,5)

fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel("Ratio")
    
plot.plotHistRatio(partialdata10["R9"],partialmc10["R9_corr"], rv2,Weight1=partialdata10["weight"],Weight2=partialmc10["weight"], Color="b")
plot.plotHistRatio(partialdata13["R9"],partialmc13["R9_corr"], rv2,Weight1=partialdata13["weight"],Weight2=partialmc13["weight"], Color="g")
plot.plotHistRatio(partialdata19["R9"],partialmc19["R9_corr"], rv2,Weight1=partialdata19["weight"],Weight2=partialmc19["weight"], Color="r")
ax.set_ylim(0,2)
#ax.set_xlim(0.9,1.1)
ax.set_title('E')
partialdata10=dfdata10.query("runperiod==3")
partialdata13=dfdata10.query("runperiod==3")
partialdata19=dfdata10.query("runperiod==3")

partialmc10=dfmc10.query("runperiod==3")
partialmc13=dfmc13.query("runperiod==3")
partialmc19=dfmc19.query("runperiod==3")

#BD
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel("R9")



plot.plotHistRatio(partialdata10["R9"],partialmc10["R9_corr"], rv,Weight1=partialdata10["weight"],Weight2=partialmc10["weight"], Color="b")
plot.plotHistRatio(partialdata13["R9"],partialmc13["R9_corr"], rv,Weight1=partialdata13["weight"],Weight2=partialmc13["weight"], Color="g")
plot.plotHistRatio(partialdata19["R9"],partialmc19["R9_corr"], rv,Weight1=partialdata19["weight"],Weight2=partialmc19["weight"], Color="r")

ax.set_title('F')
#ax.set_ylim(-5,5)

fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel("Ratio")
    
plot.plotHistRatio(partialdata10["R9"],partialmc10["R9_corr"], rv2,Weight1=partialdata10["weight"],Weight2=partialmc10["weight"], Color="b")
plot.plotHistRatio(partialdata13["R9"],partialmc13["R9_corr"], rv2,Weight1=partialdata13["weight"],Weight2=partialmc13["weight"], Color="g")
plot.plotHistRatio(partialdata19["R9"],partialmc19["R9_corr"], rv2,Weight1=partialdata19["weight"],Weight2=partialmc19["weight"], Color="r")
ax.set_ylim(0,2)
#ax.set_xlim(0.9,1.1)
ax.set_title('F')
partialdata10=dfdata10.query("runperiod==4")
partialdata13=dfdata10.query("runperiod==4")
partialdata19=dfdata10.query("runperiod==4")

partialmc10=dfmc10.query("runperiod==4")
partialmc13=dfmc13.query("runperiod==4")
partialmc19=dfmc19.query("runperiod==4")

#BD
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel("R9")



plot.plotHistRatio(partialdata10["R9"],partialmc10["R9_corr"], rv,Weight1=partialdata10["weight"],Weight2=partialmc10["weight"], Color="b")
plot.plotHistRatio(partialdata13["R9"],partialmc13["R9_corr"], rv,Weight1=partialdata13["weight"],Weight2=partialmc13["weight"], Color="g")
plot.plotHistRatio(partialdata19["R9"],partialmc19["R9_corr"], rv,Weight1=partialdata19["weight"],Weight2=partialmc19["weight"], Color="r")

ax.set_title('G')
#ax.set_ylim(-5,5)

fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel("Ratio")
    
plot.plotHistRatio(partialdata10["R9"],partialmc10["R9_corr"], rv2,Weight1=partialdata10["weight"],Weight2=partialmc10["weight"], Color="b")
plot.plotHistRatio(partialdata13["R9"],partialmc13["R9_corr"], rv2,Weight1=partialdata13["weight"],Weight2=partialmc13["weight"], Color="g")
plot.plotHistRatio(partialdata19["R9"],partialmc19["R9_corr"], rv2,Weight1=partialdata19["weight"],Weight2=partialmc19["weight"], Color="r")
ax.set_ylim(0,2)
#ax.set_xlim(0.9,1.1)
ax.set_title('G')
partialdata10=dfdata10.query("runperiod==5")
partialdata13=dfdata10.query("runperiod==5")
partialdata19=dfdata10.query("runperiod==5")

partialmc10=dfmc10.query("runperiod==5")
partialmc13=dfmc13.query("runperiod==5")
partialmc19=dfmc19.query("runperiod==5")

#BD
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel("R9")



plot.plotHistRatio(partialdata10["R9"],partialmc10["R9_corr"], rv,Weight1=partialdata10["weight"],Weight2=partialmc10["weight"], Color="b")
plot.plotHistRatio(partialdata13["R9"],partialmc13["R9_corr"], rv,Weight1=partialdata13["weight"],Weight2=partialmc13["weight"], Color="g")
plot.plotHistRatio(partialdata19["R9"],partialmc19["R9_corr"], rv,Weight1=partialdata19["weight"],Weight2=partialmc19["weight"], Color="r")

ax.set_title('H')
#ax.set_ylim(-5,5)

fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlabel("Ratio")
    
plot.plotHistRatio(partialdata10["R9"],partialmc10["R9_corr"], rv2,Weight1=partialdata10["weight"],Weight2=partialmc10["weight"], Color="b")
plot.plotHistRatio(partialdata13["R9"],partialmc13["R9_corr"], rv2,Weight1=partialdata13["weight"],Weight2=partialmc13["weight"], Color="g")
plot.plotHistRatio(partialdata19["R9"],partialmc19["R9_corr"], rv2,Weight1=partialdata19["weight"],Weight2=partialmc19["weight"], Color="r")
ax.set_ylim(0,2)
#ax.set_xlim(0.9,1.1)
ax.set_title('H')
