# %%
# some basic plots

from quantileRegression import quantileRegression
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
# Out:
# Welcome to ROOTaaS 6.06/02

# %%
# # Initialize the quantile regression object for mc
# qr_mc = quantileRegression("mc")
# # This is what you want to correct
# print "Load the mc dataframe"
# startEvtmc = 0
# stopEvtmc  = 1000000 
# qr_mc.loadDF("/Users/mauro/CMS/Physics/dataMC/nt/double_ele_spring16v2_sync_v1_mc/",
#              "cicNoSigmaIetaIeta/trees/",
#              ["DYToEE_powheg_13TeV_EBHighR9", "DYToEE_powheg_13TeV_EBLowR9", "DYToEE_powheg_13TeV_EEHighR9", "DYToEE_powheg_13TeV_EELowR9" ],
#              startEvtmc, stopEvtmc, 12345)

# %%
# Plot data, mc, mc_corrr
# just need to load the data for plotting 
qr_data = quantileRegression("data")
startEvtdata = 0
stopEvtdata   = -1
print "Load the data dataframe"
qr_data.loadDF("/Users/mauro/CMS/Physics/dataMC/nt/double_ele_spring16v2_sync_v1_ichep/",
               "cicNoSigmaIetaIeta/trees/",
               ["Data_13TeV_EBHighR9", "Data_13TeV_EBLowR9", "Data_13TeV_EEHighR9", "Data_13TeV_EELowR9" ],
               startEvtdata, stopEvtdata )
# Out:
# Load the data dataframe
# NT branches:
# ['rho', 'nvtx', 'leadHLT_Ele27_WPTight_Gsf_vMatch', 'subleadHLT_Ele27_WPTight_Gsf_vMatch', 'leadPt', 'leadScEta', 'leadPhi', 'leadR9', 'leadS4', 'leadSigmaIeIe', 'leadEtaWidth', 'leadPhiWidth', 'leadCovarianceIphiIphi', 'leadSigmaRR', 'subleadPt', 'subleadScEta', 'subleadPhi', 'subleadR9', 'subleadS4', 'subleadSigmaIeIe', 'subleadEtaWidth', 'subleadPhiWidth', 'subleadCovarianceIphiIphi', 'subleadSigmaRR']
# ['cicNoSigmaIetaIeta/trees/Data_13TeV_EBHighR9', 'cicNoSigmaIetaIeta/trees/Data_13TeV_EBLowR9', 'cicNoSigmaIetaIeta/trees/Data_13TeV_EEHighR9', 'cicNoSigmaIetaIeta/trees/Data_13TeV_EELowR9']
# Adding trees into a DataFrame
#   adding  cicNoSigmaIetaIeta/trees/Data_13TeV_EBHighR9
# rho                                    379516
# nvtx                                   379516
# leadHLT_Ele27_WPTight_Gsf_vMatch       379516
# subleadHLT_Ele27_WPTight_Gsf_vMatch    379516
# leadPt                                 379516
# leadScEta                              379516
# leadPhi                                379516
# leadR9                                 379516
# leadS4                                 379516
# leadSigmaIeIe                          379516
# leadEtaWidth                           379516
# leadPhiWidth                           379516
# leadCovarianceIphiIphi                 379516
# leadSigmaRR                            379516
# subleadPt                              379516
# subleadScEta                           379516
# subleadPhi                             379516
# subleadR9                              379516
# subleadS4                              379516
# subleadSigmaIeIe                       379516
# subleadEtaWidth                        379516
# subleadPhiWidth                        379516
# subleadCovarianceIphiIphi              379516
# subleadSigmaRR                         379516
# dtype: int64
#   adding  cicNoSigmaIetaIeta/trees/Data_13TeV_EBLowR9
# rho                                    2695968
# nvtx                                   2695968
# leadHLT_Ele27_WPTight_Gsf_vMatch       2695968
# subleadHLT_Ele27_WPTight_Gsf_vMatch    2695968
# leadPt                                 2695968
# leadScEta                              2695968
# leadPhi                                2695968
# leadR9                                 2695968
# leadS4                                 2695968
# leadSigmaIeIe                          2695968
# leadEtaWidth                           2695968
# leadPhiWidth                           2695968
# leadCovarianceIphiIphi                 2695968
# leadSigmaRR                            2695968
# subleadPt                              2695968
# subleadScEta                           2695968
# subleadPhi                             2695968
# subleadR9                              2695968
# subleadS4                              2695968
# subleadSigmaIeIe                       2695968
# subleadEtaWidth                        2695968
# subleadPhiWidth                        2695968
# subleadCovarianceIphiIphi              2695968
# subleadSigmaRR                         2695968
# dtype: int64
#   adding  cicNoSigmaIetaIeta/trees/Data_13TeV_EEHighR9
# rho                                    2783295
# nvtx                                   2783295
# leadHLT_Ele27_WPTight_Gsf_vMatch       2783295
# subleadHLT_Ele27_WPTight_Gsf_vMatch    2783295
# leadPt                                 2783295
# leadScEta                              2783295
# leadPhi                                2783295
# leadR9                                 2783295
# leadS4                                 2783295
# leadSigmaIeIe                          2783295
# leadEtaWidth                           2783295
# leadPhiWidth                           2783295
# leadCovarianceIphiIphi                 2783295
# leadSigmaRR                            2783295
# subleadPt                              2783295
# subleadScEta                           2783295
# subleadPhi                             2783295
# subleadR9                              2783295
# subleadS4                              2783295
# subleadSigmaIeIe                       2783295
# subleadEtaWidth                        2783295
# subleadPhiWidth                        2783295
# subleadCovarianceIphiIphi              2783295
# subleadSigmaRR                         2783295
# dtype: int64
#   adding  cicNoSigmaIetaIeta/trees/Data_13TeV_EELowR9
# rho                                    3820704
# nvtx                                   3820704
# leadHLT_Ele27_WPTight_Gsf_vMatch       3820704
# subleadHLT_Ele27_WPTight_Gsf_vMatch    3820704
# leadPt                                 3820704
# leadScEta                              3820704
# leadPhi                                3820704
# leadR9                                 3820704
# leadS4                                 3820704
# leadSigmaIeIe                          3820704
# leadEtaWidth                           3820704
# leadPhiWidth                           3820704
# leadCovarianceIphiIphi                 3820704
# leadSigmaRR                            3820704
# subleadPt                              3820704
# subleadScEta                           3820704
# subleadPhi                             3820704
# subleadR9                              3820704
# subleadS4                              3820704
# subleadSigmaIeIe                       3820704
# subleadEtaWidth                        3820704
# subleadPhiWidth                        3820704
# subleadCovarianceIphiIphi              3820704
# subleadSigmaRR                         3820704
# dtype: int64
# Number of events
# rho                                    3820704
# nvtx                                   3820704
# leadHLT_Ele27_WPTight_Gsf_vMatch       3820704
# subleadHLT_Ele27_WPTight_Gsf_vMatch    3820704
# leadPt                                 3820704
# leadScEta                              3820704
# leadPhi                                3820704
# leadR9                                 3820704
# leadS4                                 3820704
# leadSigmaIeIe                          3820704
# leadEtaWidth                           3820704
# leadPhiWidth                           3820704
# leadCovarianceIphiIphi                 3820704
# leadSigmaRR                            3820704
# subleadPt                              3820704
# subleadScEta                           3820704
# subleadPhi                             3820704
# subleadR9                              3820704
# subleadS4                              3820704
# subleadSigmaIeIe                       3820704
# subleadEtaWidth                        3820704
# subleadPhiWidth                        3820704
# subleadCovarianceIphiIphi              3820704
# subleadSigmaRR                         3820704
# dtype: int64
# Count df
# index                                  3820704
# rho                                    3820704
# nvtx                                   3820704
# leadHLT_Ele27_WPTight_Gsf_vMatch       3820704
# subleadHLT_Ele27_WPTight_Gsf_vMatch    3820704
# leadPt                                 3820704
# leadScEta                              3820704
# leadPhi                                3820704
# leadR9                                 3820704
# leadS4                                 3820704
# leadSigmaIeIe                          3820704
# leadEtaWidth                           3820704
# leadPhiWidth                           3820704
# leadCovarianceIphiIphi                 3820704
# leadSigmaRR                            3820704
# subleadPt                              3820704
# subleadScEta                           3820704
# subleadPhi                             3820704
# subleadR9                              3820704
# subleadS4                              3820704
# subleadSigmaIeIe                       3820704
# subleadEtaWidth                        3820704
# subleadPhiWidth                        3820704
# subleadCovarianceIphiIphi              3820704
# subleadSigmaRR                         3820704
# dtype: int64
# # lead trig   =  3217295
# # sublead trg =  2680942
# Data Sublead
# Count sublead
# rho                   3217295
# nvtx                  3217295
# Pt                    3217295
# ScEta                 3217295
# Phi                   3217295
# R9                    3217295
# S4                    3217295
# SigmaIeIe             3217295
# EtaWidth              3217295
# PhiWidth              3217295
# CovarianceIphiIphi    3217295
# SigmaRR               3217295
# dtype: int64
# Data Lead
# Count lead
# rho                   2680942
# nvtx                  2680942
# Pt                    2680942
# ScEta                 2680942
# Phi                   2680942
# R9                    2680942
# S4                    2680942
# SigmaIeIe             2680942
# EtaWidth              2680942
# PhiWidth              2680942
# CovarianceIphiIphi    2680942
# SigmaRR               2680942
# dtype: int64
# Data count
# rho                   5898237
# nvtx                  5898237
# Pt                    5898237
# ScEta                 5898237
# Phi                   5898237
# R9                    5898237
# S4                    5898237
# SigmaIeIe             5898237
# EtaWidth              5898237
# PhiWidth              5898237
# CovarianceIphiIphi    5898237
# SigmaRR               5898237
# dtype: int64
# Count final dataser
# index                 5898237
# rho                   5898237
# nvtx                  5898237
# Pt                    5898237
# ScEta                 5898237
# Phi                   5898237
# R9                    5898237
# S4                    5898237
# SigmaIeIe             5898237
# EtaWidth              5898237
# PhiWidth              5898237
# CovarianceIphiIphi    5898237
# SigmaRR               5898237
# dtype: int64
# Apply basic selection
#  ptmin  =  20.0
#  ptmax  =  60.0
#  etamin =  -2.5
#  etamax =  2.5
#  phimin =  -3.14
#  phimax =  3.14
# Reshuffle events rndm seed  =  12345
# Selecting events   [ 0 ,  5504890 ]  out of  5504890
# DataFrame size =  5504890

# %%
df = qr_data.getDF()

# %%
h = df.hist('Pt', bins=100, alpha = 1, color='g')

# %%
h = df.hist('ScEta', bins=100, alpha = 1, color='g')

# %%
h = df.hist('Phi', bins=100, alpha = 1, color='g')

# %%
h = df.hist('rho', bins=100, alpha = 1, color='g')

# %%
h = df.hist('nvtx', bins=100, alpha = 1, color='g')

# %%
df = df.query('R9>0.8')
h = df.hist('R9', bins=100, alpha = 1, color='g')

# %%
dfEB = df.query('abs(ScEta)<1.444 & R9>0.8')
h = dfEB.hist('R9', bins=100, alpha = 1, color='g')

# %%
dfEB = df.query('abs(ScEta)>1.57 & R9>0.8')
h = dfEB.hist('R9', bins=100, alpha = 1, color='g')
