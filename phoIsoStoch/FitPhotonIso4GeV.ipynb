# %%
import photonIsoCorrect as pic
# reload(pic)
# Out:
# Welcome to ROOTaaS 6.06/08

# %%
import numpy as np

rhobins = np.linspace(0,21.,8)
isobins = np.linspace(0,4.,101)

# %%
pic.runEtaBin(("exo/spring16/tnpTuples_ichep/Formatted_output_SingleElectron.root",
               "tnpAna/TaPTree"),
              ("exo/spring16/tnpTuples_ichep/Formatted_output_DYToEE_NNPDF30_13TeV-powheg-pythia8__63mb.root",
               "tnpAna/TaPTree"),
              rhobins, isobins, "low_eta","(abs(probe_eta)>=0 && abs(probe_eta)<0.9)")
# Out:
# (<ROOT.TTree object ("TaPTree") at 0x665dd70>, 'hdata_')
# hdata_low_eta_0_3
# hdata_low_eta_3_6
# hdata_low_eta_6_9
# hdata_low_eta_9_12
# hdata_low_eta_12_15
# hdata_low_eta_15_18
# hdata_low_eta_18_21
# (<ROOT.TTree object ("TaPTree") at 0x6735640>, 'hmc_')
# hmc_low_eta_0_3
# hmc_low_eta_3_6
# hmc_low_eta_6_9
# hmc_low_eta_9_12
# hmc_low_eta_12_15
# hmc_low_eta_15_18
# hmc_low_eta_18_21
# [(0.0, 3.0), (3.0, 6.0), (6.0, 9.0), (9.0, 12.0), (12.0, 15.0), (15.0, 18.0), (18.0, 21.0)]
# [ 0.    0.04  0.08  0.12  0.16  0.2   0.24  0.28  0.32  0.36  0.4   0.44
#   0.48  0.52  0.56  0.6   0.64  0.68  0.72  0.76  0.8   0.84  0.88  0.92
#   0.96  1.    1.04  1.08  1.12  1.16  1.2   1.24  1.28  1.32  1.36  1.4
#   1.44  1.48  1.52  1.56  1.6   1.64  1.68  1.72  1.76  1.8   1.84  1.88
#   1.92  1.96  2.    2.04  2.08  2.12  2.16  2.2   2.24  2.28  2.32  2.36
#   2.4   2.44  2.48  2.52  2.56  2.6   2.64  2.68  2.72  2.76  2.8   2.84
# ...

# %%
pic.runEtaBin(("exo/spring16/tnpTuples_ichep/Formatted_output_SingleElectron.root",
               "tnpAna/TaPTree"),
              ("exo/spring16/tnpTuples_ichep/Formatted_output_DYToEE_NNPDF30_13TeV-powheg-pythia8__63mb.root",
               "tnpAna/TaPTree"),
              rhobins, isobins, "mid_eta","(abs(probe_eta)>=0.9 && abs(probe_eta)<1.5)")
# Out:
# (<ROOT.TTree object ("TaPTree") at 0x7406bf0>, 'hdata_')
# hdata_mid_eta_0_3
# hdata_mid_eta_3_6
# hdata_mid_eta_6_9
# hdata_mid_eta_9_12
# hdata_mid_eta_12_15
# hdata_mid_eta_15_18
# hdata_mid_eta_18_21
# (<ROOT.TTree object ("TaPTree") at 0x8389820>, 'hmc_')
# hmc_mid_eta_0_3
# hmc_mid_eta_3_6
# hmc_mid_eta_6_9
# hmc_mid_eta_9_12
# hmc_mid_eta_12_15
# hmc_mid_eta_15_18
# hmc_mid_eta_18_21
# [(0.0, 3.0), (3.0, 6.0), (6.0, 9.0), (9.0, 12.0), (12.0, 15.0), (15.0, 18.0), (18.0, 21.0)]
# [ 0.    0.04  0.08  0.12  0.16  0.2   0.24  0.28  0.32  0.36  0.4   0.44
#   0.48  0.52  0.56  0.6   0.64  0.68  0.72  0.76  0.8   0.84  0.88  0.92
#   0.96  1.    1.04  1.08  1.12  1.16  1.2   1.24  1.28  1.32  1.36  1.4
#   1.44  1.48  1.52  1.56  1.6   1.64  1.68  1.72  1.76  1.8   1.84  1.88
#   1.92  1.96  2.    2.04  2.08  2.12  2.16  2.2   2.24  2.28  2.32  2.36
#   2.4   2.44  2.48  2.52  2.56  2.6   2.64  2.68  2.72  2.76  2.8   2.84
# ...

# %%
# rhobins = np.linspace(0,25.,6)

pic.runEtaBin(("exo/spring16/tnpTuples_ichep/Formatted_output_SingleElectron.root",
               "tnpAna/TaPTree"),
              ("exo/spring16/tnpTuples_ichep/Formatted_output_DYToEE_NNPDF30_13TeV-powheg-pythia8__63mb.root",
               "tnpAna/TaPTree"),
              rhobins, isobins, "ee_mid_eta","(abs(probe_eta)>1.5 && abs(probe_eta)<2)")
# Out:
# (<ROOT.TTree object ("TaPTree") at 0x7596cd0>, 'hdata_')
# hdata_ee_mid_eta_0_3
# hdata_ee_mid_eta_3_6
# hdata_ee_mid_eta_6_9
# hdata_ee_mid_eta_9_12
# hdata_ee_mid_eta_12_15
# hdata_ee_mid_eta_15_18
# hdata_ee_mid_eta_18_21
# (<ROOT.TTree object ("TaPTree") at 0x93d7f60>, 'hmc_')
# hmc_ee_mid_eta_0_3
# hmc_ee_mid_eta_3_6
# hmc_ee_mid_eta_6_9
# hmc_ee_mid_eta_9_12
# hmc_ee_mid_eta_12_15
# hmc_ee_mid_eta_15_18
# hmc_ee_mid_eta_18_21
# [(0.0, 3.0), (3.0, 6.0), (6.0, 9.0), (9.0, 12.0), (12.0, 15.0), (15.0, 18.0), (18.0, 21.0)]
# [ 0.    0.04  0.08  0.12  0.16  0.2   0.24  0.28  0.32  0.36  0.4   0.44
#   0.48  0.52  0.56  0.6   0.64  0.68  0.72  0.76  0.8   0.84  0.88  0.92
#   0.96  1.    1.04  1.08  1.12  1.16  1.2   1.24  1.28  1.32  1.36  1.4
#   1.44  1.48  1.52  1.56  1.6   1.64  1.68  1.72  1.76  1.8   1.84  1.88
#   1.92  1.96  2.    2.04  2.08  2.12  2.16  2.2   2.24  2.28  2.32  2.36
#   2.4   2.44  2.48  2.52  2.56  2.6   2.64  2.68  2.72  2.76  2.8   2.84
# ...

# %%
pic.runEtaBin(("exo/spring16/tnpTuples_ichep/Formatted_output_SingleElectron.root",
               "tnpAna/TaPTree"),
              ("exo/spring16/tnpTuples_ichep/Formatted_output_DYToEE_NNPDF30_13TeV-powheg-pythia8__63mb.root",
               "tnpAna/TaPTree"),
              rhobins, isobins, "ee_high_eta","(abs(probe_eta)>=2 && abs(probe_eta)<2.5)")
# Out:
# (<ROOT.TTree object ("TaPTree") at 0x83deb00>, 'hdata_')
# hdata_ee_high_eta_0_3
# hdata_ee_high_eta_3_6
# hdata_ee_high_eta_6_9
# hdata_ee_high_eta_9_12
# hdata_ee_high_eta_12_15
# hdata_ee_high_eta_15_18
# hdata_ee_high_eta_18_21
# (<ROOT.TTree object ("TaPTree") at 0x93d91f0>, 'hmc_')
# hmc_ee_high_eta_0_3
# hmc_ee_high_eta_3_6
# hmc_ee_high_eta_6_9
# hmc_ee_high_eta_9_12
# hmc_ee_high_eta_12_15
# hmc_ee_high_eta_15_18
# hmc_ee_high_eta_18_21
# [(0.0, 3.0), (3.0, 6.0), (6.0, 9.0), (9.0, 12.0), (12.0, 15.0), (15.0, 18.0), (18.0, 21.0)]
# [ 0.    0.04  0.08  0.12  0.16  0.2   0.24  0.28  0.32  0.36  0.4   0.44
#   0.48  0.52  0.56  0.6   0.64  0.68  0.72  0.76  0.8   0.84  0.88  0.92
#   0.96  1.    1.04  1.08  1.12  1.16  1.2   1.24  1.28  1.32  1.36  1.4
#   1.44  1.48  1.52  1.56  1.6   1.64  1.68  1.72  1.76  1.8   1.84  1.88
#   1.92  1.96  2.    2.04  2.08  2.12  2.16  2.2   2.24  2.28  2.32  2.36
#   2.4   2.44  2.48  2.52  2.56  2.6   2.64  2.68  2.72  2.76  2.8   2.84
# ...

# %%
pic.runEtaBin(("exo/spring16/tnpTuples_ichep/Formatted_output_SingleElectron.root",
               "tnpAna/TaPTree"),
              ("exo/spring16/tnpTuples_ichep/Formatted_output_DYToEE_NNPDF30_13TeV-powheg-pythia8__63mb.root",
               "tnpAna/TaPTree"),
              rhobins, isobins, "ee_high_eta2p3","(abs(probe_eta)>=2 && abs(probe_eta)<2.3)")
# Out:
# (<ROOT.TTree object ("TaPTree") at 0x93265d0>, 'hdata_')
# hdata_ee_high_eta2p3_0_3
# hdata_ee_high_eta2p3_3_6
# hdata_ee_high_eta2p3_6_9
# hdata_ee_high_eta2p3_9_12
# hdata_ee_high_eta2p3_12_15
# hdata_ee_high_eta2p3_15_18
# hdata_ee_high_eta2p3_18_21
# (<ROOT.TTree object ("TaPTree") at 0xa688ef0>, 'hmc_')
# hmc_ee_high_eta2p3_0_3
# hmc_ee_high_eta2p3_3_6
# hmc_ee_high_eta2p3_6_9
# hmc_ee_high_eta2p3_9_12
# hmc_ee_high_eta2p3_12_15
# hmc_ee_high_eta2p3_15_18
# hmc_ee_high_eta2p3_18_21
# [(0.0, 3.0), (3.0, 6.0), (6.0, 9.0), (9.0, 12.0), (12.0, 15.0), (15.0, 18.0), (18.0, 21.0)]
# [ 0.    0.04  0.08  0.12  0.16  0.2   0.24  0.28  0.32  0.36  0.4   0.44
#   0.48  0.52  0.56  0.6   0.64  0.68  0.72  0.76  0.8   0.84  0.88  0.92
#   0.96  1.    1.04  1.08  1.12  1.16  1.2   1.24  1.28  1.32  1.36  1.4
#   1.44  1.48  1.52  1.56  1.6   1.64  1.68  1.72  1.76  1.8   1.84  1.88
#   1.92  1.96  2.    2.04  2.08  2.12  2.16  2.2   2.24  2.28  2.32  2.36
# ...
